# %%
#Storing new flavours
flavours = ["cinnamon", "pumpkin", "apple pie"]
print("New flavours: ")
print(flavours)

#Storing ratings and results
ratings = [4, 2.5, 3]
print("Consumer ratings: ")
print(ratings)

passed = [True, False, True]
print("Release: ")
print(passed)
