# %%
stock = 75
item = webcams
order = 15

print(f"{stock} {item} in stock")

print(f"{order} customer orders")

print(f"{stock - order} available")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc4181ab23d5> in <module>()
#       1 stock = 75
# ----> 2 item = webcams
#       3 order = 15
#       4
#       5 print(f"{stock} {item} in stock")
#
# NameError: name 'webcams' is not defined
