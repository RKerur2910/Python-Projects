# %%
apple_stocks = [298.18, 304.18, 289.23]

#Updating the newest value
apple_stocks[0] = 310
print("Latest value:")
print(apple_stocks[0])

#Updating the highest value
apple_stocks[1] = 310
print("Highest value:")
print(apple_stocks[1])

print("Lowest value:")
print(apple_stocks[2])
# Out:
# Latest value:
# 310
# Highest value:
# 310
# Lowest value:
# 289.23
